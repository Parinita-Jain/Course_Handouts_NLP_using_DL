# %%
import nltk

# tokenization
from nltk.tokenize import word_tokenize
nltk.download('punkt')

# stopword removal
from nltk.corpus import stopwords
nltk.download('stopwords')

# punctuation removal
from string import punctuation

# lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
english_stopwords = stopwords.words("english")
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_document(document):
  tokens = word_tokenize(document.lower())
  clean_tokens = [token for token in tokens if token not in english_stopwords]
  clean_tokens = [token for token in clean_tokens if token not in punctuation]
  clean_tokens = [lemmatizer.lemmatize(token) for token in clean_tokens]
  clean_tokens = [lemmatizer.lemmatize(token,"v") for token in clean_tokens]
  return clean_tokens

# %%
document1 = '''The Indian Premier League (IPL) (also known as the TATA IPL for sponsorship reasons) is a men's Twenty20 (T20) cricket league held annually in India and contested by ten city-based franchise teams.[3][4] The league was founded by the Board of Control for Cricket in India in 2007. The competition is usually held in the summer months (between March and May) every year and has an exclusive window in the ICC Future Tours Programme, meaning that less international cricket tours take place during the IPL seasons.[5]
The IPL is the most popular cricket league in the world, and in 2014 it was ranked sixth by average attendance among all sports leagues.[6][needs update] In 2010, the IPL became the first sporting event in the world to be broadcast live on YouTube.[7][8] The brand value of the IPL in 2022 was ₹90,038 crore (US$11 billion).[9] According to BCCI, the 2015 IPL season contributed ₹1,150 crore (US$140 million) to the GDP of the India.[10] In December 2022, the league became a decacorn valued at $10.9 billion registering a 75% growth in dollar terms since 2020 when it was valued at $6.2 billion, according to a report by consulting firm D & P Advisory.[11]
There have been fifteen seasons of the tournament. The current title holders are the Gujarat Titans, winning the 2022 edition by defeating Rajasthan Royals in the final game.'''

# %%
clean_tokens1 = preprocess_document(document1)
print(clean_tokens1)
# Out:
# ['indian', 'premier', 'league', 'ipl', 'also', 'know', 'tata', 'ipl', 'sponsorship', 'reason', 'men', "'s", 'twenty20', 't20', 'cricket', 'league', 'hold', 'annually', 'india', 'contest', 'ten', 'city-based', 'franchise', 'team', '3', '4', 'league', 'found', 'board', 'control', 'cricket', 'india', '2007.', 'competition', 'usually', 'hold', 'summer', 'month', 'march', 'may', 'every', 'year', 'exclusive', 'window', 'icc', 'future', 'tour', 'programme', 'mean', 'le', 'international', 'cricket', 'tour', 'take', 'place', 'ipl', 'season', '5', 'ipl', 'popular', 'cricket', 'league', 'world', '2014', 'rank', 'sixth', 'average', 'attendance', 'among', 'sport', 'league', '6', 'need', 'update', '2010', 'ipl', 'become', 'first', 'sport', 'event', 'world', 'broadcast', 'live', 'youtube', '7', '8', 'brand', 'value', 'ipl', '2022', '₹90,038', 'crore', 'u', '11', 'billion', '9', 'accord', 'bcci', '2015', 'ipl', 'season', 'contribute', '₹1,150', 'crore', 'u', '140', 'million', 'gdp', 'india', '10', 'december', '2022', 'league', 'become', 'decacorn', 'value', '10.9', 'billion', 'register', '75', 'growth', 'dollar', 'term', 'since', '2020', 'value', '6.2', 'billion', 'accord', 'report', 'consult', 'firm', 'p', 'advisory', '11', 'fifteen', 'season', 'tournament', 'current', 'title', 'holder', 'gujarat', 'titan', 'win', '2022', 'edition', 'defeat', 'rajasthan', 'royal', 'final', 'game']

# %%
document2 = '''Virat Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] (listen); born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team who plays as a right-handed batsman for Royal Challengers Bangalore in the IPL and for the Delhi in Indian domestic cricket. 
Widely regarded as one of the greatest batsmen of all time,[4] Kohli holds the records for scoring most runs in T20 internationals and in the IPL. In 2020, the International Cricket Council named him the male cricketer of the decade. Kohli has also contributed to a number of India's successes, including winning the 2011 World Cup and the 2013 Champions trophy.'''

# %%
clean_tokens2 = preprocess_document(document2)
print(clean_tokens2)
# Out:
# ['virat', 'kohli', 'hindi', 'pronunciation', 'ʋɪˈɾɑːʈ', 'ˈkoːɦli', 'listen', 'bear', '5', 'november', '1988', 'indian', 'international', 'cricketer', 'former', 'captain', 'indian', 'national', 'cricket', 'team', 'play', 'right-handed', 'batsman', 'royal', 'challenger', 'bangalore', 'ipl', 'delhi', 'indian', 'domestic', 'cricket', 'widely', 'regard', 'one', 'greatest', 'batsman', 'time', '4', 'kohli', 'hold', 'record', 'score', 'run', 't20', 'international', 'ipl', '2020', 'international', 'cricket', 'council', 'name', 'male', 'cricketer', 'decade', 'kohli', 'also', 'contribute', 'number', 'india', "'s", 'success', 'include', 'win', '2011', 'world', 'cup', '2013', 'champion', 'trophy']

# %% [markdown]
# ## Reading data from file

# %%
file = open("/content/drive/MyDrive/DL SK 21 3 23/NLP /Code and Data/rohit.txt")
document3 = file.read()
file.close()

# %%
clean_tokens3 = preprocess_document(document3)
print(clean_tokens3)
# Out:
# ['rohit', 'gurunath', 'sharma', 'bear', '30', 'april', '1987', 'indian', 'international', 'cricketer', 'current', 'captain', 'india', 'men', '’', 'cricket', 'team', 'format', 'consider', 'one', 'best', 'batsman', 'generation', 'one', 'greatest', 'open', 'batter', 'time', '3', 'sharma', 'know', 'time', 'elegance', 'six-hitting', 'ability', 'leadership', 'skill', 'play', 'right-handed', 'batsman', 'india', 'national', 'cricket', 'team', 'international', 'cricket', 'mumbai', 'indian', 'ipl', 'mumbai', 'domestic', 'cricket', 'rohit', 'also', 'captain', 'mumbai', 'indian', 'team', '5', 'title', 'leadership', 'team', 'india', 'sharma', 'member', 'team', '2007', 't20', 'world', 'cup', '2013', 'icc', 'champion', 'trophy', 'play', 'final', 'tournament', 'sharma', 'currently', 'hold', 'world', 'record', 'highest', 'individual', 'score', '264', 'one', 'day', 'international', 'odi', 'match', 'player', 'score', 'three', 'double-centuries', 'odis', 'also', 'hold', 'record', 'score', 'hundred', 'five', 'single', 'cricket', 'world', 'cup', 'icc', 'men', "'s", 'odi', 'cricketer', 'year', 'award', '2019.', 'sharma', 'receive', 'two', 'national', 'honour', 'arjuna', 'award', '2015', 'prestigious', 'major', 'dhyan', 'chand', 'khel', 'ratna', '2020.', 'captaincy', 'india', '2018', 'asia', 'cup', 'seventh', 'time', 'country', 'title', 'outside', 'cricket', 'sharma', 'active', 'supporter', 'animal', 'welfare', 'campaign', 'official', 'rhino', 'ambassador', 'wwf-india', 'member', 'people', 'ethical', 'treatment', 'animal', 'peta', 'work', 'peta', 'campaign', 'raise', 'awareness', 'plight', 'homeless', 'cat', 'dog', 'india']

# %% [markdown]
# # POS Tagging

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos_tokens1 = nltk.pos_tag(clean_tokens1)
print(pos_tokens1)
# Out:
# [('indian', 'JJ'), ('premier', 'NN'), ('league', 'NN'), ('ipl', 'NN'), ('also', 'RB'), ('know', 'VBP'), ('tata', 'NNS'), ('ipl', 'JJ'), ('sponsorship', 'JJ'), ('reason', 'NN'), ('men', 'NNS'), ("'s", 'POS'), ('twenty20', 'NN'), ('t20', 'NN'), ('cricket', 'NN'), ('league', 'NN'), ('hold', 'VBP'), ('annually', 'RB'), ('india', 'JJ'), ('contest', 'NN'), ('ten', 'IN'), ('city-based', 'JJ'), ('franchise', 'NN'), ('team', 'NN'), ('3', 'CD'), ('4', 'CD'), ('league', 'NN'), ('found', 'VBD'), ('board', 'NN'), ('control', 'NN'), ('cricket', 'NN'), ('india', 'VBP'), ('2007.', 'CD'), ('competition', 'NN'), ('usually', 'RB'), ('hold', 'VB'), ('summer', 'NN'), ('month', 'NN'), ('march', 'NN'), ('may', 'MD'), ('every', 'DT'), ('year', 'NN'), ('exclusive', 'JJ'), ('window', 'NN'), ('icc', 'JJ'), ('future', 'JJ'), ('tour', 'NN'), ('programme', 'NN'), ('mean', 'NN'), ('le', 'VBP'), ('international', 'JJ'), ('cricket', 'NN'), ('tour', 'NNS'), ('take', 'VBP'), ('place', 'NN'), ('ipl', 'NN'), ('season', 'NN'), ('5', 'CD'), ('ipl', 'NN'), ('popular', 'JJ'), ('cricket', 'NN'), ('league', 'NN'), ('world', 'NN'), ('2014', 'CD'), ('rank', 'NN'), ('sixth', 'JJ'), ('average', 'JJ'), ('attendance', 'NN'), ('among', 'IN'), ('sport', 'JJ'), ('league', 'NN'), ('6', 'CD'), ('need', 'NN'), ('update', 'JJ'), ('2010', 'CD'), ('ipl', 'NN'), ('become', 'VBN'), ('first', 'JJ'), ('sport', 'JJ'), ('event', 'NN'), ('world', 'NN'), ('broadcast', 'NN'), ('live', 'JJ'), ('youtube', 'NN'), ('7', 'CD'), ('8', 'CD'), ('brand', 'NN'), ('value', 'NN'), ('ipl', 'NN'), ('2022', 'CD'), ('₹90,038', 'NN'), ('crore', 'VBD'), ('u', 'JJ'), ('11', 'CD'), ('billion', 'CD'), ('9', 'CD'), ('accord', 'NN'), ('bcci', 'NN'), ('2015', 'CD'), ('ipl', 'NN'), ('season', 'NN'), ('contribute', 'NN'), ('₹1,150', 'NNP'), ('crore', 'NN'), ('u', 'JJ'), ('140', 'CD'), ('million', 'CD'), ('gdp', 'NN'), ('india', 'NN'), ('10', 'CD'), ('december', 'NN'), ('2022', 'CD'), ('league', 'NN'), ('become', 'VBN'), ('decacorn', 'JJ'), ('value', 'NN'), ('10.9', 'CD'), ('billion', 'CD'), ('register', 'NN'), ('75', 'CD'), ('growth', 'NN'), ('dollar', 'NN'), ('term', 'NN'), ('since', 'IN'), ('2020', 'CD'), ('value', 'NN'), ('6.2', 'CD'), ('billion', 'CD'), ('accord', 'JJ'), ('report', 'NN'), ('consult', 'NN'), ('firm', 'NN'), ('p', 'VBD'), ('advisory', 'JJ'), ('11', 'CD'), ('fifteen', 'JJ'), ('season', 'NN'), ('tournament', 'NN'), ('current', 'JJ'), ('title', 'NN'), ('holder', 'NN'), ('gujarat', 'NN'), ('titan', 'NN'), ('win', 'NN'), ('2022', 'CD'), ('edition', 'NN'), ('defeat', 'NN'), ('rajasthan', 'NN'), ('royal', 'VBP'), ('final', 'JJ'), ('game', 'NN')]

# %%
for element in pos_tokens1:
  if element[1] in ["NN", "NNS", "NNP", "NNPS"]:
    print(element[0])
# Out:
# premier
# league
# ipl
# tata
# reason
# men
# twenty20
# t20
# cricket
# league
# contest
# franchise
# team
# league
# board
# control
# cricket
# competition
# summer
# month
# march
# year
# window
# tour
# programme
# mean
# cricket
# tour
# place
# ipl
# season
# ipl
# cricket
# league
# world
# rank
# attendance
# league
# need
# ipl
# event
# world
# broadcast
# youtube
# brand
# value
# ipl
# ₹90,038
# accord
# bcci
# ipl
# season
# contribute
# ₹1,150
# crore
# gdp
# india
# december
# league
# value
# register
# growth
# dollar
# term
# value
# report
# consult
# firm
# season
# tournament
# title
# holder
# gujarat
# titan
# win
# edition
# defeat
# rajasthan
# game

# %% [markdown]
# ## Named Entity Recognition

# %%
# spacy
import spacy

# %%
# load a pretrained langauge model
model = spacy.load('en_core_web_sm')

# %%
clean_document1 = " ".join(clean_tokens1)
print(clean_document1)
# Out:
# indian premier league ipl also know tata ipl sponsorship reason men 's twenty20 t20 cricket league hold annually india contest ten city-based franchise team 3 4 league found board control cricket india 2007. competition usually hold summer month march may every year exclusive window icc future tour programme mean le international cricket tour take place ipl season 5 ipl popular cricket league world 2014 rank sixth average attendance among sport league 6 need update 2010 ipl become first sport event world broadcast live youtube 7 8 brand value ipl 2022 ₹90,038 crore u 11 billion 9 accord bcci 2015 ipl season contribute ₹1,150 crore u 140 million gdp india 10 december 2022 league become decacorn value 10.9 billion register 75 growth dollar term since 2020 value 6.2 billion accord report consult firm p advisory 11 fifteen season tournament current title holder gujarat titan win 2022 edition defeat rajasthan royal final game

# %%
result = model(clean_document1)

# %%
for entity in result.ents:
  print(entity, entity.label_)
# Out:
# indian NORP
# premier league ipl ORG
# tata ipl sponsorship reason ORG
# annually DATE
# india GPE
# ten CARDINAL
# 3 4 league MONEY
# india GPE
# 2007 DATE
# summer month DATE
# 5 CARDINAL
# 2014 DATE
# sixth ORDINAL
# 6 CARDINAL
# 2010 DATE
# first ORDINAL
# 7 8 CARDINAL
# 2022 DATE
# ₹ ORG
# 90,038 CARDINAL
# 11 billion MONEY
# 9 DATE
# 2015 ipl season DATE
# ₹ ORG
# 1,150 MONEY
# 140 million CARDINAL
# india GPE
# 10 december 2022 DATE
# 10.9 billion MONEY
# 2020 DATE
# 6.2 billion CARDINAL
# 11 fifteen DATE
# gujarat GPE
# 2022 DATE

# %%
clean_document2 = " ".join(clean_tokens2)
print(clean_document2)
# Out:
# virat kohli hindi pronunciation ʋɪˈɾɑːʈ ˈkoːɦli listen bear 5 november 1988 indian international cricketer former captain indian national cricket team play right-handed batsman royal challenger bangalore ipl delhi indian domestic cricket widely regard one greatest batsman time 4 kohli hold record score run t20 international ipl 2020 international cricket council name male cricketer decade kohli also contribute number india 's success include win 2011 world cup 2013 champion trophy

# %%
result = model(clean_document2)
for entity in result.ents:
  print(entity, entity.label_)
# Out:
# virat kohli hindi pronunciation ʋɪˈɾɑːʈ ORG
# 5 CARDINAL
# november 1988 DATE
# indian NORP
# indian NORP
# ipl delhi GPE
# indian NORP
# one CARDINAL
# 4 CARDINAL
# 2020 CARDINAL
# decade DATE
# india GPE
# 2011 world cup QUANTITY
# 2013 DATE

# %%
clean_document3 = " ".join(clean_tokens3)
print(clean_document3)
# Out:
# rohit gurunath sharma bear 30 april 1987 indian international cricketer current captain india men ’ cricket team format consider one best batsman generation one greatest open batter time 3 sharma know time elegance six-hitting ability leadership skill play right-handed batsman india national cricket team international cricket mumbai indian ipl mumbai domestic cricket rohit also captain mumbai indian team 5 title leadership team india sharma member team 2007 t20 world cup 2013 icc champion trophy play final tournament sharma currently hold world record highest individual score 264 one day international odi match player score three double-centuries odis also hold record score hundred five single cricket world cup icc men 's odi cricketer year award 2019. sharma receive two national honour arjuna award 2015 prestigious major dhyan chand khel ratna 2020. captaincy india 2018 asia cup seventh time country title outside cricket sharma active supporter animal welfare campaign official rhino ambassador wwf-india member people ethical treatment animal peta work peta campaign raise awareness plight homeless cat dog india

# %%
result = model(clean_document3)
for entity in result.ents:
  print(entity, entity.label_)
# Out:
# sharma NORP
# 30 april 1987 DATE
# indian NORP
# india GPE
# one CARDINAL
# 3 CARDINAL
# sharma NORP
# six CARDINAL
# india GPE
# indian NORP
# mumbai GPE
# indian NORP
# 5 CARDINAL
# india GPE
# sharma PRODUCT
# 2007 DATE
# 2013 CARDINAL
# sharma NORP
# 264 CARDINAL
# three CARDINAL
# centuries DATE
# score hundred five CARDINAL
# year DATE
# 2019 DATE
# sharma ORG
# two CARDINAL
# 2015 DATE
# 2020 CARDINAL
# india GPE
# 2018 DATE
# asia cup EVENT
# seventh ORDINAL
# sharma PRODUCT
# india GPE

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wc = WordCloud(width = 800, height = 800, 
              background_color ='white',  
              min_font_size = 10)

wc.generate(clean_document1)

plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
wc = WordCloud(width = 800, height = 800, 
              background_color ='white',  
              min_font_size = 10)

wc.generate(clean_document2)

plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
wc = WordCloud(width = 800, height = 800, 
              background_color ='white',  
              min_font_size = 10)

wc.generate(clean_document3)

plt.imshow(wc)
plt.axis("off")
plt.show()
