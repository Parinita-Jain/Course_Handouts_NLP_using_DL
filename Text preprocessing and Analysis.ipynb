# %%
document = '''The Indian Premier League (IPL) (also known as the TATA IPL for sponsorship reasons) is a men's Twenty20 (T20) cricket league held annually in India and contested by ten city-based franchise teams.[3][4] The league was founded by the Board of Control for Cricket in India in 2007. The competition is usually held in the summer months (between March and May) every year and has an exclusive window in the ICC Future Tours Programme, meaning that less international cricket tours take place during the IPL seasons.[5]
The IPL is the most popular cricket league in the world, and in 2014 it was ranked sixth by average attendance among all sports leagues.[6][needs update] In 2010, the IPL became the first sporting event in the world to be broadcast live on YouTube.[7][8] The brand value of the IPL in 2022 was ₹90,038 crore (US$11 billion).[9] According to BCCI, the 2015 IPL season contributed ₹1,150 crore (US$140 million) to the GDP of the India.[10] In December 2022, the league became a decacorn valued at $10.9 billion registering a 75% growth in dollar terms since 2020 when it was valued at $6.2 billion, according to a report by consulting firm D & P Advisory.[11]
There have been fifteen seasons of the tournament. The current title holders are the Gujarat Titans, winning the 2022 edition by defeating Rajasthan Royals in the final game.'''

# %%
print(document)
# Out:
# The Indian Premier League (IPL) (also known as the TATA IPL for sponsorship reasons) is a men's Twenty20 (T20) cricket league held annually in India and contested by ten city-based franchise teams.[3][4] The league was founded by the Board of Control for Cricket in India in 2007. The competition is usually held in the summer months (between March and May) every year and has an exclusive window in the ICC Future Tours Programme, meaning that less international cricket tours take place during the IPL seasons.[5]
# ...

# %%
words = document.split()
print(words)
# Out:
# ['The', 'Indian', 'Premier', 'League', '(IPL)', '(also', 'known', 'as', 'the', 'TATA', 'IPL', 'for', 'sponsorship', 'reasons)', 'is', 'a', "men's", 'Twenty20', '(T20)', 'cricket', 'league', 'held', 'annually', 'in', 'India', 'and', 'contested', 'by', 'ten', 'city-based', 'franchise', 'teams.[3][4]', 'The', 'league', 'was', 'founded', 'by', 'the', 'Board', 'of', 'Control', 'for', 'Cricket', 'in', 'India', 'in', '2007.', 'The', 'competition', 'is', 'usually', 'held', 'in', 'the', 'summer', 'months', '(between', 'March', 'and', 'May)', 'every', 'year', 'and', 'has', 'an', 'exclusive', 'window', 'in', 'the', 'ICC', 'Future', 'Tours', 'Programme,', 'meaning', 'that', 'less', 'international', 'cricket', 'tours', 'take', 'place', 'during', 'the', 'IPL', 'seasons.[5]', 'The', 'IPL', 'is', 'the', 'most', 'popular', 'cricket', 'league', 'in', 'the', 'world,', 'and', 'in', '2014', 'it', 'was', 'ranked', 'sixth', 'by', 'average', 'attendance', 'among', 'all', 'sports', 'leagues.[6][needs', 'upda
# ...

# %% [markdown]
# # Tokenization

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tokens = word_tokenize(document)
print(tokens)
# Out:
# ['The', 'Indian', 'Premier', 'League', '(', 'IPL', ')', '(', 'also', 'known', 'as', 'the', 'TATA', 'IPL', 'for', 'sponsorship', 'reasons', ')', 'is', 'a', 'men', "'s", 'Twenty20', '(', 'T20', ')', 'cricket', 'league', 'held', 'annually', 'in', 'India', 'and', 'contested', 'by', 'ten', 'city-based', 'franchise', 'teams', '.', '[', '3', ']', '[', '4', ']', 'The', 'league', 'was', 'founded', 'by', 'the', 'Board', 'of', 'Control', 'for', 'Cricket', 'in', 'India', 'in', '2007', '.', 'The', 'competition', 'is', 'usually', 'held', 'in', 'the', 'summer', 'months', '(', 'between', 'March', 'and', 'May', ')', 'every', 'year', 'and', 'has', 'an', 'exclusive', 'window', 'in', 'the', 'ICC', 'Future', 'Tours', 'Programme', ',', 'meaning', 'that', 'less', 'international', 'cricket', 'tours', 'take', 'place', 'during', 'the', 'IPL', 'seasons', '.', '[', '5', ']', 'The', 'IPL', 'is', 'the', 'most', 'popular', 'cricket', 'league', 'in', 'the', 'world', ',', 'and', 'in', '2014', 'it', 'was', 'ranked', 
# ...

# %%
len(tokens)
# Out:
# 294

# %% [markdown]
# # Stopwords Removal

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
english_stopwords = stopwords.words("english")
print(english_stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
#clean_tokens = []
#for token in tokens:
#  if token not in english_stopwords:
#    clean_tokens.append(token)


clean_tokens = [token for token in tokens if token not in english_stopwords]

print(clean_tokens)
# Out:
# ['The', 'Indian', 'Premier', 'League', '(', 'IPL', ')', '(', 'also', 'known', 'TATA', 'IPL', 'sponsorship', 'reasons', ')', 'men', "'s", 'Twenty20', '(', 'T20', ')', 'cricket', 'league', 'held', 'annually', 'India', 'contested', 'ten', 'city-based', 'franchise', 'teams', '.', '[', '3', ']', '[', '4', ']', 'The', 'league', 'founded', 'Board', 'Control', 'Cricket', 'India', '2007', '.', 'The', 'competition', 'usually', 'held', 'summer', 'months', '(', 'March', 'May', ')', 'every', 'year', 'exclusive', 'window', 'ICC', 'Future', 'Tours', 'Programme', ',', 'meaning', 'less', 'international', 'cricket', 'tours', 'take', 'place', 'IPL', 'seasons', '.', '[', '5', ']', 'The', 'IPL', 'popular', 'cricket', 'league', 'world', ',', '2014', 'ranked', 'sixth', 'average', 'attendance', 'among', 'sports', 'leagues', '.', '[', '6', ']', '[', 'needs', 'update', ']', 'In', '2010', ',', 'IPL', 'became', 'first', 'sporting', 'event', 'world', 'broadcast', 'live', 'YouTube', '.', '[', '7', ']', '[', '8', 
# ...

# %%
len(clean_tokens)
# Out:
# 216

# %% [markdown]
# # Remove Punctuations

# %%
from string import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
clean_tokens = [token for token in clean_tokens if token not in punctuation]
print(clean_tokens)

print(len(clean_tokens))
# Out:
# ['The', 'Indian', 'Premier', 'League', 'IPL', 'also', 'known', 'TATA', 'IPL', 'sponsorship', 'reasons', 'men', "'s", 'Twenty20', 'T20', 'cricket', 'league', 'held', 'annually', 'India', 'contested', 'ten', 'city-based', 'franchise', 'teams', '3', '4', 'The', 'league', 'founded', 'Board', 'Control', 'Cricket', 'India', '2007', 'The', 'competition', 'usually', 'held', 'summer', 'months', 'March', 'May', 'every', 'year', 'exclusive', 'window', 'ICC', 'Future', 'Tours', 'Programme', 'meaning', 'less', 'international', 'cricket', 'tours', 'take', 'place', 'IPL', 'seasons', '5', 'The', 'IPL', 'popular', 'cricket', 'league', 'world', '2014', 'ranked', 'sixth', 'average', 'attendance', 'among', 'sports', 'leagues', '6', 'needs', 'update', 'In', '2010', 'IPL', 'became', 'first', 'sporting', 'event', 'world', 'broadcast', 'live', 'YouTube', '7', '8', 'The', 'brand', 'value', 'IPL', '2022', '₹90,038', 'crore', 'US', '11', 'billion', '9', 'According', 'BCCI', '2015', 'IPL', 'season', 'contribute
# ...

# %% [markdown]
# # Stemming and Lemmatization

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()
stemmer.stem("studied")
# Out:
# 'studi'

# %%
stemmer.stem("playing")
# Out:
# 'play'

# %%
stemmer.stem("wolves")
# Out:
# 'wolv'

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize("wolves")
# Out:
# 'wolf'

# %%
lemmatizer.lemmatize("feet")
# Out:
# 'foot'

# %%
# “v” for verbs, “a” for adjectives, “r” for adverbs
lemmatizer.lemmatize("studied","v")
# Out:
# 'study'

# %%
lemmatizer.lemmatize("playing","v")
# Out:
# 'play'

# %%
lemmatizer.lemmatize("later","a")
# Out:
# 'late'

# %%
lemmatizer.lemmatize("better","a")
# Out:
# 'good'

# %%
clean_tokens = [lemmatizer.lemmatize(token) for token in clean_tokens]
clean_tokens = [lemmatizer.lemmatize(token,"v") for token in clean_tokens]

print(clean_tokens)
# Out:
# ['The', 'Indian', 'Premier', 'League', 'IPL', 'also', 'know', 'TATA', 'IPL', 'sponsorship', 'reason', 'men', "'s", 'Twenty20', 'T20', 'cricket', 'league', 'hold', 'annually', 'India', 'contest', 'ten', 'city-based', 'franchise', 'team', '3', '4', 'The', 'league', 'found', 'Board', 'Control', 'Cricket', 'India', '2007', 'The', 'competition', 'usually', 'hold', 'summer', 'month', 'March', 'May', 'every', 'year', 'exclusive', 'window', 'ICC', 'Future', 'Tours', 'Programme', 'mean', 'le', 'international', 'cricket', 'tour', 'take', 'place', 'IPL', 'season', '5', 'The', 'IPL', 'popular', 'cricket', 'league', 'world', '2014', 'rank', 'sixth', 'average', 'attendance', 'among', 'sport', 'league', '6', 'need', 'update', 'In', '2010', 'IPL', 'become', 'first', 'sport', 'event', 'world', 'broadcast', 'live', 'YouTube', '7', '8', 'The', 'brand', 'value', 'IPL', '2022', '₹90,038', 'crore', 'US', '11', 'billion', '9', 'According', 'BCCI', '2015', 'IPL', 'season', 'contribute', '₹1,150', 'crore', '
# ...
